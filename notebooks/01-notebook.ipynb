# %%
import pandas as pd

df = pd.read_csv("../data/processed/macro_panel.csv")

print("Rows:", len(df))
print("Countries:", df["country"].nunique())
print("Min month:", df["month"].min())
print("Max month:", df["month"].max())

# Check balanced panel
counts = df.groupby("country")["month"].count()
print(counts)
# Out:
# Rows: 1176
# Countries: 7
# Min month: 2010-01
# Max month: 2023-12
# country
# AT    168
# DE    168
# ES    168
# FI    168
# FR    168
# IT    168
# NL    168
# Name: month, dtype: int64
